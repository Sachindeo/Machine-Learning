# %%
#Getting data from Google Trend
# !pip install pytrends

# %%
# #API to fetch the search volume of a specific "keyword" using Google trend
# from pytrends.request import TrendReq
# pytrends = TrendReq(hl='en-US', tz=360)

# #Building the Payload
# kw_list = ['Apparel', 'Caps', 'Sunglasses']
# pytrends.build_payload(kw_list, cat=0, timeframe='today 5-y', geo='US', gprop='')
# df=pytrends.interest_over_time()
# df.head(8)
# df=pytrends.get_historical_interest(kw_list, year_start=2015, month_start=1, year_end=2018, month_end=12, cat=0, geo='US', gprop='', sleep=0)
# Out:
#             Apparel  Caps  Sunglasses isPartial
# date
# 2014-08-24       40    20          40     False
# 2014-08-31       42    21          41     False
# 2014-09-07       43    20          35     False
# 2014-09-14       42    21          32     False
# 2014-09-21       40    21          31     False
# 2014-09-28       42    22          30     False
# 2014-10-05       43    22          28     False
# 2014-10-12       43    22          28     False

# %%
# webguid='0402f0c3-ae84-4df4-9b6d-66c83df5f5c8'     #IMC
webguid='44f3629f-8e08-438d-9c3d-9060dd765ec3'   #Imagen AI
# webguid='B004168A-6400-4582-824A-CF1ACAC0FAC0'   #Positive Promotion
# webguid='7dfe37b3-fd4f-490f-873a-2f0541c81b65'   #ai.ewizsaas

# %%
import pandas as pd
import numpy as np
from pymongo import MongoClient
from pandas.io.json import json_normalize as jnz
import datetime as datetime
import json
import dask.dataframe as dd

# %%
#CREATING CONNECTION WITH MONGO DB
conn = MongoClient("mongodb://ewizai:Sxdfhgd6D8cMJ2334@54.241.73.148:27017/ewizai-alpha")

db = conn["ewizai-alpha"]
product_collection = db["Products"]
category_collection = db["Categories"]
user_collection=db["Users"]
trend_collection=db['IndustryTrendCategories']

# %%
# data = pd.DataFrame(list(table_object.find()))
trend_data = pd.DataFrame(list(trend_collection.find({"WebsiteGuid": webguid})))
trend_data_x=trend_data[['Categories', 'SubCategories']]
Industry_trend_data=trend_data_x.dropna(axis=0, inplace=False)
Industry_trend_data.reset_index(drop=True, inplace=True)

# %%
Industry_trend_data.head(5)
# Out:
#                          Categories  \
# 0                   Custom apparels
# 1               Writing Instruments
# 2                       custom Bags
# 3                         Drinkware
# 4  Desk/Office/Business Accessories
#
#                                        SubCategories
# 0  Camo, Mesh Back, Stars & Stripes, Structured, ...
# 1  Highlighters, Metal Pens, Stylus Pens, Pencils...
# 2  Waterproof Bags, Messengers, Fashion Totes, No...
# 3  Ceramic Mugs, Coleman, Drinkware Accessories, ...
# 4  Padfolios, Travel, Wallets, Portfolios, Card C...

# %%
keyword=[]
def Getting_Keywords(row):
    for x in (row['SubCategories'].split(", ")):
        keyword.append(x)
                
Blank=Industry_trend_data.apply(Getting_Keywords,axis=1)
print(keyword)
# Out:
# ['Camo', 'Mesh Back', 'Stars & Stripes', 'Structured', 'Unstructured', 'Visors', 'Highlighters', 'Metal Pens', 'Stylus Pens', 'Pencils', 'Plastic Pens', 'Novelty Pens', 'Waterproof Bags', 'Messengers', 'Fashion Totes', 'Non-Woven Totes', 'Duffels', 'Cotton Totes', 'Drawstrings', '600D Totes', 'Shopper Totes', 'Accessory Bags', 'Garment Bags', 'Bags', 'Backpacks', 'Ceramic Mugs', 'Coleman', 'Drinkware Accessories', 'Flat Bottles', 'Gift Boxes', 'Housewares', 'Plastic Tumblers And Cups', 'Sports Bottles', 'Stainless Tumblers', 'Tritan Bottles', 'Padfolios', 'Travel', 'Wallets', 'Portfolios', 'Card Cases', 'PRESS-N-STICK™ FOUR COLOR PADS', 'Magna-Stick™ Headers', 'Specialty Calendars', 'Specialty Headers', 'Super-Size Headers', 'Custom Headers', 'Four color headers', 'Accessories', 'Overseas', 'Flashlights', 'Rainwear', 'Compact Umbrellas', 'Stick Umbrellas', 'Vented Compact Umbrellas', 'Inverted Umbrellas', 'Golf Umbrellas', 'Tools', 'Blankets', 'Games', 'Fitness Accessories', 'Fitness
# ...

# %%
#API to fetch the search volume of a specific "keyword" using Google trend
from pytrends.request import TrendReq
pytrends = TrendReq(hl='en-US', tz=360)

#Building the Payload
kw_list = ['Drinkware']
pytrends.build_payload(kw_list, cat=0, timeframe='today 3-m', geo='US', gprop='')
df=pytrends.interest_over_time()
df.head(8)
# Out:
#             Drinkware  isPartial
# date
# 2019-05-22         37      False
# 2019-05-23         42      False
# 2019-05-24         62      False
# 2019-05-25         34      False
# 2019-05-26         58      False
# 2019-05-27         32      False
# 2019-05-28         27      False
# 2019-05-29         40      False

# %%
lis= ['Camo', 'Mesh Back', 'Stars & Stripes', 'Structured', 'Unstructured', 'Visors', 'Highlighters', 'Metal Pens', 'Stylus Pens', 'Pencils', 'Plastic Pens', 'Novelty Pens', 'Waterproof Bags', 'Messengers', 'Fashion Totes', 'Non-Woven Totes', 'Duffels']
# lis= ['Camels', 'Mesh', 'pens', "bottels",  "ants", "soaps"]
i=0
while i<len(lis):
    kw_list= lis[i:i+4]
    print(kw_list)
    pytrends.build_payload(kw_list, cat=0, timeframe='today 3-m', geo='US', gprop='')
    df_test=pytrends.interest_over_time()
    print(df_test)
    df.join(df_test, how='outer')
    i=i+4
     

    
# for item in lis:
#     kw_list.append(item)
#     print(kw_list)
#     pytrends.build_payload(kw_list, cat=0, timeframe='today 3-m', geo='US', gprop='')
#     df_test=pytrends.interest_over_time()
#     df.join(df_test)
# Out:
# ['Camo', 'Mesh Back', 'Stars & Stripes', 'Structured']
#             Camo  Mesh Back  Stars & Stripes  Structured  isPartial
# date
# 2019-05-22    62          1                0          12      False
# 2019-05-23    60          2                0          12      False
# 2019-05-24    75          1                0          11      False
# 2019-05-25    69          1                1           5      False
# 2019-05-26    79          1                0           5      False
# 2019-05-27    74          1                1           5      False
# 2019-05-28    66          1                0          11      False
# 2019-05-29    64          1                0           9      False
# 2019-05-30    68          1                0          14      False
# 2019-05-31    66          1                0          11      False
# 2019-06-01    75          2                1           5      False
# 2019-06-02    80          2                0           3      False
# ...

# %%
# !pip install autocorrect
import autocorrect

# %%
# lis= ['Camo', 'Mesh Back', 'Stars & Stripes', 'Structured', 'Unstructured', 'Visors', 'Highlighters', 'Metal Pens', 'Stylus Pens', 'Pencils', 'Plastic Pens', 'Novelty Pens', 'Waterproof Bags', 'Messengers', 'Fashion Totes', 'Non-Woven Totes', 'Duffels']
# # lis= ['Camels', 'Mesh', 'pens', "bottels",  "ants", "soaps"]
# df_list=[]
# i=0
# df=pd.DataFrame()
# while i<len(lis):
#     kw_list= lis[i:i+4]
#     print(kw_list)
#     pytrends.build_payload(kw_list, cat=0, timeframe='today 3-m', geo='US', gprop='')
#     df_test=pytrends.interest_over_time()
# #     df.append(df_test)
#     df_list.append(df_test)
#     i=i+4

# %%
# keyword= ['Camo', 'Mesh Back', 'Stars & Stripes', 'Structured', 'Unstructured', 'Visors', 'Highlighters', 'Metal Pens', 'Stylus Pens', 'Pencils', 'Plastic Pens', 'Novelty Pens', 'Waterproof Bags', 'Messengers', 'Fashion Totes', 'Non-Woven Totes', 'Duffels']
# lis= ['Camels', 'Mesh', 'pens', "bottels",  "ants", "soaps"]
df_list=[]
i=0
df=pd.DataFrame()
while i<len(keyword):
    kw_list= keyword[i:i+5]
    print(kw_list)
    pytrends.build_payload(kw_list, cat=0, timeframe='today 3-m', geo='US', gprop='')
    df_temp=pytrends.interest_over_time()
    df_list.append(df_temp)
    i=i+5
    
df_new=pd.concat(df_list, axis=1)
df_new
# Out:
# ['Camo', 'Mesh Back', 'Stars & Stripes', 'Structured', 'Unstructured']
# ['Visors', 'Highlighters', 'Metal Pens', 'Stylus Pens', 'Pencils']
# ['Plastic Pens', 'Novelty Pens', 'Waterproof Bags', 'Messengers', 'Fashion Totes']
# ['Non-Woven Totes', 'Duffels', 'Cotton Totes', 'Drawstrings', '600D Totes']
# ['Shopper Totes', 'Accessory Bags', 'Garment Bags', 'Bags', 'Backpacks']
# ['Ceramic Mugs', 'Coleman', 'Drinkware Accessories', 'Flat Bottles', 'Gift Boxes']
# ['Housewares', 'Plastic Tumblers And Cups', 'Sports Bottles', 'Stainless Tumblers', 'Tritan Bottles']
# ['Padfolios', 'Travel', 'Wallets', 'Portfolios', 'Card Cases']
# ['PRESS-N-STICK™ FOUR COLOR PADS', 'Magna-Stick™ Headers', 'Specialty Calendars', 'Specialty Headers', 'Super-Size Headers']
# ['Custom Headers', 'Four color headers', 'Accessories', 'Overseas', 'Flashlights']
# ['Rainwear', 'Compact Umbrellas', 'Stick Umbrellas', 'Vented Compact Umbrellas', 'Inverted Umbrellas']
# ...

# %%
df_list
# Out:
# [            Camo  Mesh Back  Stars & Stripes  Structured  isPartial
#  date
#  2019-05-22    62          1                0          12      False
#  2019-05-23    60          2                0          12      False
#  2019-05-24    75          1                0          11      False
#  2019-05-25    69          1                1           5      False
#  2019-05-26    79          1                0           5      False
#  2019-05-27    74          1                1           5      False
#  2019-05-28    66          1                0          11      False
#  2019-05-29    64          1                0           9      False
#  2019-05-30    68          1                0          14      False
#  2019-05-31    66          1                0          11      False
#  2019-06-01    75          2                1           5      False
#  2019-06-02    80          2                0           3      False
# ...

# %%
df_new=pd.concat(df_list, axis=1)

# %%
df_new
# Out:
#             Camo  Mesh Back  Stars & Stripes  Structured  Unstructured  \
# date
# 2019-05-22    62          1                0          12             2
# 2019-05-23    60          2                0          12             2
# 2019-05-24    75          1                0          11             2
# 2019-05-25    69          1                1           5             1
# 2019-05-26    79          1                0           5             2
# 2019-05-27    74          1                1           5             2
# 2019-05-28    66          1                0          11             1
# 2019-05-29    64          1                0           9             2
# 2019-05-30    68          1                0          14             1
# 2019-05-31    66          1                0          11             1
# 2019-06-01    75          2                1           5             1
# 2019-06-02    80          2                0           3             2
# ...

# %%
df_final=df_new.loc[:,~df_new.columns.str.contains('isPartial')]

# %%
df_final.head(5)
# Out:
#             Camo  Mesh Back  Stars & Stripes  Structured  Unstructured  \
# date
# 2019-05-23    61          1                0          10             2
# 2019-05-24    74          2                0          10             1
# 2019-05-25    71          1                1           6             1
# 2019-05-26    75          1                1           5             1
# 2019-05-27    80          1                0           5             2
#
#             Visors  Highlighters  Metal Pens  Stylus Pens  Pencils  \
# date
# 2019-05-23      16             5           1            2       48
# 2019-05-24      17             4           1            1       46
# 2019-05-25      17             4           0            1       39
# 2019-05-26      14             2           0            2       33
# 2019-05-27      18             4           2            0       34
#
#             Plastic Pens  Novelty Pens  Waterproof Bags  Messengers  \
# date
# ...

# %%
#Google Trend using API (Part-1)
keyword= ['Camo', 'Mesh Back', 'Stars & Stripes', 'Structured', 'Unstructured', 'Visors', 'Highlighters', 'Metal Pens', 'Stylus Pens', 'Pencils', 'Plastic Pens', 'Novelty Pens', 'Waterproof Bags', 'Messengers', 'Fashion Totes', 'Non-Woven Totes', 'Duffels']
# lis= ['Camels', 'Mesh', 'pens', "bottels",  "ants", "soaps"]
df_list=[]
i=0
df=pd.DataFrame()
while i<len(keyword):
    kw_list= keyword[i:i+5]
    print(kw_list)
    pytrends.build_payload(kw_list, cat=0, timeframe='today 3-m', geo='US', gprop='')
    df_temp=pytrends.interest_over_time()
    df_list.append(df_temp)
    i=i+5
    
df_new=pd.concat(df_list, axis=1)
df_search_volume=df_new.loc[:,~df_new.columns.str.contains('isPartial')]
df_search_volume
# Out:
# ['Camo', 'Mesh Back', 'Stars & Stripes', 'Structured', 'Unstructured']
# ['Visors', 'Highlighters', 'Metal Pens', 'Stylus Pens', 'Pencils']
# ['Plastic Pens', 'Novelty Pens', 'Waterproof Bags', 'Messengers', 'Fashion Totes']
# ['Non-Woven Totes', 'Duffels']
#             Camo  Mesh Back  Stars & Stripes  Structured  Unstructured  \
# date
# 2019-05-23    61          1                0          10             2
# 2019-05-24    74          2                0          10             1
# 2019-05-25    71          1                1           6             1
# 2019-05-26    75          1                1           5             1
# 2019-05-27    80          1                0           5             2
# 2019-05-28    66          2                1          10             1
# 2019-05-29    66          1                0          10             2
# 2019-05-30    67          1                0          11             1
# 2019-05-31    69          2                0          12             1
# ...

# %%
#Google Trend using API (Part-2)
# keyword= ['Camo', 'Mesh Back', 'Stars & Stripes', 'Structured', 'Unstructured', 'Visors', 'Highlighters', 'Metal Pens', 'Stylus Pens', 'Pencils', 'Plastic Pens', 'Novelty Pens', 'Waterproof Bags', 'Messengers', 'Fashion Totes', 'Non-Woven Totes', 'Duffels']
# lis= ['Camels', 'Mesh', 'pens', "bottels",  "ants", "soaps"]
df_list=[]
group_list=[]
i=0
j=0
df=pd.DataFrame()

while j<len(keyword):
    group_list=keyword[j:j+40]
    print("Outer loop")
    print(len(group_list))
    i=0
    while i<len(group_list):
        kw_list= group_list[i:i+5]
        print(kw_list)
        pytrends.build_payload(kw_list, cat=0, timeframe='today 3-m', geo='US', gprop='')
        df_temp=pytrends.interest_over_time()
        df_list.append(df_temp)
        i=i+5
    j=j+40
    
df_new=pd.concat(df_list, axis=1)
df_search_volume=df_new.loc[:,~df_new.columns.str.contains('isPartial')]
df_search_volume
# Out:
# Outer loop
# 40
# ['Camo', 'Mesh Back', 'Stars & Stripes', 'Structured', 'Unstructured']
# ['Visors', 'Highlighters', 'Metal Pens', 'Stylus Pens', 'Pencils']
# ['Plastic Pens', 'Novelty Pens', 'Waterproof Bags', 'Messengers', 'Fashion Totes']
# ['Non-Woven Totes', 'Duffels', 'Cotton Totes', 'Drawstrings', '600D Totes']
# ['Shopper Totes', 'Accessory Bags', 'Garment Bags', 'Bags', 'Backpacks']
# ['Ceramic Mugs', 'Coleman', 'Drinkware Accessories', 'Flat Bottles', 'Gift Boxes']
# ['Housewares', 'Plastic Tumblers And Cups', 'Sports Bottles', 'Stainless Tumblers', 'Tritan Bottles']
# ['Padfolios', 'Travel', 'Wallets', 'Portfolios', 'Card Cases']
# Outer loop
# 30
# ['PRESS-N-STICK™ FOUR COLOR PADS', 'Magna-Stick™ Headers', 'Specialty Calendars', 'Specialty Headers', 'Super-Size Headers']
# ['Custom Headers', 'Four color headers', 'Accessories', 'Overseas', 'Flashlights']
# ['Rainwear', 'Compact Umbrellas', 'Stick Umbrellas', 'Vented Compact Umbrellas', 'Inverted Umbrellas']
# ...

# %%
len(df_search_volume.columns)
# Out:
# 65

# %%
len(keyword)
# Out:
# 70
